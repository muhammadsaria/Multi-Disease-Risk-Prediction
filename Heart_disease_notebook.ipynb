# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.impute import SimpleImputer

# %%
data = pd.read_csv("HeartDisease_Uncleaned_WithNoise.csv")

# %%
data.head()
# Out:
#   age     sex chest_pain_type resting_blood_pressure cholestoral  \
# 0  52    Male  Typical angina                    125         212
# 1  53    Male  Typical angina                    140         203
# 2  70    Male  Typical angina                    145         174
# 3  61    Male  Typical angina                    148         203
# 4  62  Female  Typical angina                    138         294
#
#       fasting_blood_sugar               rest_ecg Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality            168
# 1  Greater than 120 mg/ml                 Normal            155
# 2    Lower than 120 mg/ml  ST-T wave abnormality            125
# 3    Lower than 120 mg/ml  ST-T wave abnormality            161
# 4  Greater than 120 mg/ml  ST-T wave abnormality            106
#
#   exercise_induced_angina oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No     1.0  Downsloping                           Two
# 1                     Yes     3.1    Upsloping                          Zero
# 2                     Yes     2.6    Upsloping                          Zero
# 3                      No     0.0  Downsloping                           One
# 4                      No     1.9         Flat                         Three
#
#          thalassemia target
# 0  Reversable Defect      0
# 1  Reversable Defect      0
# 2  Reversable Defect      0
# 3  Reversable Defect      0
# 4       Fixed Defect      0

# %%
data.describe()
# Out:
#          age   sex chest_pain_type resting_blood_pressure cholestoral  \
# count   1113  1144            1144                   1128        1136
# unique    46     5               6                     75         178
# top       58  Male  Typical angina                    120        high
# freq      68   744             526                    128          59
#
#          fasting_blood_sugar               rest_ecg Max_heart_rate  \
# count                   1147                   1149           1124
# unique                     4                      5            104
# top     Lower than 120 mg/ml  ST-T wave abnormality           fast
# freq                     913                    546             45
#
#        exercise_induced_angina oldpeak slope vessels_colored_by_flourosopy  \
# count                     1151    1115  1137                          1151
# unique                       4      48     5                             7
# top                         No     0.0  Flat                          Zero
# freq                       722     329   482                           612
#
#          thalassemia target
# count           1154   1141
# unique             7      4
# top     Fixed Defect      1
# freq             571    554

# %%
data.isnull().sum()
# Out:
# age                              62
# sex                              31
# chest_pain_type                  31
# resting_blood_pressure           47
# cholestoral                      39
# fasting_blood_sugar              28
# rest_ecg                         26
# Max_heart_rate                   51
# exercise_induced_angina          24
# oldpeak                          60
# slope                            38
# vessels_colored_by_flourosopy    24
# thalassemia                      21
# target                           34
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            1113 non-null   object
#  1   sex                            1144 non-null   object
#  2   chest_pain_type                1144 non-null   object
#  3   resting_blood_pressure         1128 non-null   object
#  4   cholestoral                    1136 non-null   object
#  5   fasting_blood_sugar            1147 non-null   object
#  6   rest_ecg                       1149 non-null   object
#  7   Max_heart_rate                 1124 non-null   object
#  8   exercise_induced_angina        1151 non-null   object
#  9   oldpeak                        1115 non-null   object
#  10  slope                          1137 non-null   object
#  11  vessels_colored_by_flourosopy  1151 non-null   object
#  12  thalassemia                    1154 non-null   object
#  13  target                         1141 non-null   object
# dtypes: object(14)
# memory usage: 128.6+ KB

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        print("---------------------------------")
        print("Info of",col)
        print("----------------------------------")
        print(data[col].value_counts())
# Out:
# ---------------------------------
# Info of age
# ----------------------------------
# age
# 58       68
# 57       58
# forty    53
# 54       53
# 59       46
# 52       43
# 56       41
# 51       39
# 62       39
# 44       39
# 60       39
# 64       35
# 67       33
# 63       33
# 41       32
# 61       32
# 55       30
# 65       28
# 43       27
# 66       27
# 53       26
# 45       26
# 42       26
# 48       23
# 46       23
# 50       22
# 47       19
# 49       18
# 35       16
# 39       14
# 70       14
# 38       12
# 68       12
# 71       11
# 40       11
# 69       10
# 34        7
# 37        6
# 29        5
# 76        4
# 74        4
# 77        3
# 73        3
# 31        1
# 75        1
# 33        1
# Name: count, dtype: int64
# ---------------------------------
# Info of sex
# ----------------------------------
# sex
# Male      744
# Female    312
# male       31
# MALE       29
# M          28
# Name: count, dtype: int64
# ---------------------------------
# Info of chest_pain_type
# ----------------------------------
# chest_pain_type
# Typical angina      526
# Non-anginal pain    284
# Atypical angina     167
# Asymptomatic         77
# typical Angina       46
# Atypical             44
# Name: count, dtype: int64
# ---------------------------------
# Info of resting_blood_pressure
# ----------------------------------
# resting_blood_pressure
# 120    128
# 130    123
# 140    109
# 110     64
# 150     55
#       ...
# 99       1
# 158      1
# 161      1
# 127      1
# 167      1
# Name: count, Length: 75, dtype: int64
# ---------------------------------
# Info of cholestoral
# ----------------------------------
# cholestoral
# high    59
# 234     22
# 204     21
# 197     19
# 212     18
#         ..
# 165      1
# 135      1
# 346      1
# 329      1
# 374      1
# Name: count, Length: 178, dtype: int64
# ---------------------------------
# Info of fasting_blood_sugar
# ----------------------------------
# fasting_blood_sugar
# Lower than 120 mg/ml      913
# Greater than 120 mg/ml    153
# HIGH                       43
# lower                      38
# Name: count, dtype: int64
# ---------------------------------
# Info of rest_ecg
# ----------------------------------
# rest_ecg
# ST-T wave abnormality           546
# Normal                          527
# normal                           35
# abnormal                         26
# Left ventricular hypertrophy     15
# Name: count, dtype: int64
# ---------------------------------
# Info of Max_heart_rate
# ----------------------------------
# Max_heart_rate
# fast    45
# 162     35
# 160     33
# 163     29
# 152     29
#         ..
# 102      1
# 77       1
# 83       1
# 81       1
# 72       1
# Name: count, Length: 104, dtype: int64
# ---------------------------------
# Info of exercise_induced_angina
# ----------------------------------
# exercise_induced_angina
# No     722
# Yes    371
# no      30
# yes     28
# Name: count, dtype: int64
# ---------------------------------
# Info of oldpeak
# ----------------------------------
# oldpeak
# 0.0    329
# 1.2     59
# 1.0     52
# 0.8     47
# 0.6     47
# 1.4     46
# low     43
# 1.6     38
# 0.2     38
# 1.8     37
# 2.0     32
# 0.4     30
# 2.8     24
# 0.1     23
# 2.6     21
# 0.5     17
# 3.0     17
# 1.5     17
# 1.9     16
# 3.6     15
# 2.2     14
# 4.0     13
# 2.4     12
# 0.9     11
# 3.4     11
# 0.3     10
# 2.3      9
# 3.2      8
# 5.6      8
# 2.5      7
# 4.2      7
# 1.3      6
# 3.8      6
# 1.1      6
# 4.4      5
# 3.5      4
# 0.7      4
# 2.9      4
# 2.1      4
# 3.1      4
# 6.2      3
# 4.9      3
# 4.6      2
# 5.1      2
# 6.0      1
# 4.1      1
# 5.0      1
# 3.7      1
# Name: count, dtype: int64
# ---------------------------------
# Info of slope
# ----------------------------------
# slope
# Flat            482
# Downsloping     469
# Upsloping       109
# Down sloping     40
# Flat             37
# Name: count, dtype: int64
# ---------------------------------
# Info of vessels_colored_by_flourosopy
# ----------------------------------
# vessels_colored_by_flourosopy
# Zero       612
# One        245
# Two        157
# Three       69
# unknown     27
# three       23
# Four        18
# Name: count, dtype: int64
# ---------------------------------
# Info of thalassemia
# ----------------------------------
# thalassemia
# Fixed Defect         571
# Reversable Defect    410
# Normal                99
# normal                23
# Reversable            22
# Defect                22
# No                     7
# Name: count, dtype: int64
# ---------------------------------
# Info of target
# ----------------------------------
# target
# 1      554
# 0      525
# no      37
# yes     25
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

def clean_heart_data(df):

    for col in df.columns:
        df[col] = df[col].astype(str).str.lower().str.strip()
        df[col] = df[col].replace("nan", np.nan)


    df['age'] = df['age'].replace({'forty': '40'})
    df['cholestoral'] = df['cholestoral'].replace({'high': np.nan})
    df['Max_heart_rate'] = df['Max_heart_rate'].replace({'fast': np.nan})
    df['oldpeak'] = df['oldpeak'].replace({'low': np.nan})
    df['thalassemia'] = df['thalassemia'].replace({'no': np.nan})


    replace_map = {
        'zero': 0,
        'one': 1,
        'two': 2,
        'three': 3,
        'four': 4,
        'unknown': np.nan
    }
    df['vessels_colored_by_flourosopy'] = df['vessels_colored_by_flourosopy'].replace(replace_map)


    df['target'] = df['target'].replace({'1.0': 1, '0.0': 0, '1': 1, '0': 0})


    numeric_cols = [
        'age', 'resting_blood_pressure', 'cholestoral',
        'Max_heart_rate', 'oldpeak', 'vessels_colored_by_flourosopy', 'target'
    ]
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')


    df['sex'] = df['sex'].replace({'m': 'male', 'f': 'female'})

    df['chest_pain_type'] = df['chest_pain_type'].replace({
        'typical angina': 'typical angina',
        'atypical': 'atypical angina',
        'non-anginal pain': 'non-anginal pain',
        'asymptomatic': 'asymptomatic'
    })

    df['fasting_blood_sugar'] = df['fasting_blood_sugar'].replace({
        'lower than 120 mg/ml': 'low',
        'greater than 120 mg/ml': 'high',
        'lower': 'low',
        'higher': 'high'
    })

    df['rest_ecg'] = df['rest_ecg'].replace({
        'normal': 'normal',
        'st-t wave abnormality': 'abnormal',
        'left ventricular hypertrophy': 'abnormal',
        'abnormal': 'abnormal'
    })

    df['exercise_induced_angina'] = df['exercise_induced_angina'].replace({
        'yes': 'yes', 'no': 'no'
    })

    df['slope'] = df['slope'].replace({
        'upsloping': 'upsloping',
        'flat': 'flat',
        'down sloping': 'downsloping',
        'downsloping': 'downsloping'
    })

    df['thalassemia'] = df['thalassemia'].replace({
        'normal': 'normal',
        'fixed defect': 'fixed',
        'reversable defect': 'reversable',
        'reversable': 'reversable'
    })

    return df
data = clean_heart_data(data)
# Out:
# C:\Users\ESHOP\AppData\Local\Temp\ipykernel_10444\635394168.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['vessels_colored_by_flourosopy'] = df['vessels_colored_by_flourosopy'].replace(replace_map)

# %%
print("After cleaning:")
print(data['age'].value_counts(dropna=False))
print(data['cholestoral'].value_counts(dropna=False))
print(data['Max_heart_rate'].value_counts(dropna=False))
print(data['oldpeak'].value_counts(dropna=False))
print(data['vessels_colored_by_flourosopy'].value_counts(dropna=False))
print(data['thalassemia'].value_counts(dropna=False))
print(data['target'].value_counts(dropna=False))
# Out:
# After cleaning:
# age
# 58.0    68
# 40.0    64
# NaN     62
# 57.0    58
# 54.0    53
# 59.0    46
# 52.0    43
# 56.0    41
# 51.0    39
# 62.0    39
# 44.0    39
# 60.0    39
# 64.0    35
# 67.0    33
# 63.0    33
# 61.0    32
# 41.0    32
# 55.0    30
# 65.0    28
# 66.0    27
# 43.0    27
# 45.0    26
# 42.0    26
# 53.0    26
# 48.0    23
# 46.0    23
# 50.0    22
# 47.0    19
# 49.0    18
# 35.0    16
# 39.0    14
# 70.0    14
# 68.0    12
# 38.0    12
# 71.0    11
# 69.0    10
# 34.0     7
# 37.0     6
# 29.0     5
# 76.0     4
# 74.0     4
# 77.0     3
# 73.0     3
# 31.0     1
# 75.0     1
# 33.0     1
# Name: count, dtype: int64
# cholestoral
# NaN      98
# 234.0    22
# 204.0    21
# 197.0    19
# 212.0    18
#          ..
# 165.0     1
# 135.0     1
# 346.0     1
# 329.0     1
# 374.0     1
# Name: count, Length: 178, dtype: int64
# Max_heart_rate
# NaN      96
# 162.0    35
# 160.0    33
# 163.0    29
# 152.0    29
#          ..
# 102.0     1
# 77.0      1
# 83.0      1
# 81.0      1
# 72.0      1
# Name: count, Length: 104, dtype: int64
# oldpeak
# 0.0    329
# NaN    103
# 1.2     59
# 1.0     52
# 0.8     47
# 0.6     47
# 1.4     46
# 1.6     38
# 0.2     38
# 1.8     37
# 2.0     32
# 0.4     30
# 2.8     24
# 0.1     23
# 2.6     21
# 0.5     17
# 3.0     17
# 1.5     17
# 1.9     16
# 3.6     15
# 2.2     14
# 4.0     13
# 2.4     12
# 0.9     11
# 3.4     11
# 0.3     10
# 2.3      9
# 3.2      8
# 5.6      8
# 2.5      7
# 4.2      7
# 1.3      6
# 3.8      6
# 1.1      6
# 4.4      5
# 3.5      4
# 0.7      4
# 2.9      4
# 2.1      4
# 3.1      4
# 6.2      3
# 4.9      3
# 4.6      2
# 5.1      2
# 6.0      1
# 4.1      1
# 5.0      1
# 3.7      1
# Name: count, dtype: int64
# vessels_colored_by_flourosopy
# 0.0    612
# 1.0    245
# 2.0    157
# 3.0     92
# NaN     51
# 4.0     18
# Name: count, dtype: int64
# thalassemia
# fixed         571
# reversable    432
# normal        122
# NaN            28
# defect         22
# Name: count, dtype: int64
# target
# 1.0    554
# 0.0    525
# NaN     96
# Name: count, dtype: int64

# %%
data['target'].value_counts()
# Out:
# target
# 1.0    554
# 0.0    525
# Name: count, dtype: int64

# %%
data['target'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target'>

# %%
data['age'] = pd.to_numeric(data['age'], errors='coerce')
data['resting_blood_pressure'] = pd.to_numeric(data['resting_blood_pressure'], errors='coerce')
data['cholestoral'] = pd.to_numeric(data['cholestoral'], errors='coerce')
data['Max_heart_rate'] = pd.to_numeric(data['Max_heart_rate'], errors='coerce')
data['oldpeak'] = pd.to_numeric(data['oldpeak'], errors='coerce')
data['vessels_colored_by_flourosopy'] = pd.to_numeric(data['vessels_colored_by_flourosopy'], errors='coerce')
data['target'] = pd.to_numeric(data['target'], errors='coerce')

# %%
# Split data into features and target
X = data.drop('target', axis=1)
y = data['target']

# %%
cat_cols = [
    'sex',
    'chest_pain_type',
    'fasting_blood_sugar',
    'rest_ecg',
    'exercise_induced_angina',
    'slope',
    'thalassemia'
]


num_cols = data.select_dtypes(include=['float64', 'int64']).columns
num_imputer = SimpleImputer(strategy='median')
data[num_cols] = num_imputer.fit_transform(data[num_cols])

cat_imputer = SimpleImputer(strategy='most_frequent')
data[cat_cols] = cat_imputer.fit_transform(data[cat_cols])


label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))
    label_encoders[col] = le


X = data.drop('target', axis=1)
y = data['target']


y_le = LabelEncoder()
y_encoded = y_le.fit_transform(y)


num_cols = X.select_dtypes(include=['float64', 'int64']).columns

# %%
correlation_matrix = data[num_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %%
data.isnull().sum()
# Out:
# age                              0
# sex                              0
# chest_pain_type                  0
# resting_blood_pressure           0
# cholestoral                      0
# fasting_blood_sugar              0
# rest_ecg                         0
# Max_heart_rate                   0
# exercise_induced_angina          0
# oldpeak                          0
# slope                            0
# vessels_colored_by_flourosopy    0
# thalassemia                      0
# target                           0
# dtype: int64

# %%
for col in num_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data[col] = data[col].clip(lower=lower_bound, upper=upper_bound)

# %%
for col in num_cols:
  plt.figure(figsize=(12,6))
  sns.boxplot(y=data[col])
  plt.title(f"Boxplot of {col}")
  plt.show()

# %%
# Prepare features and target
X = data.drop('target', axis=1)
y = data['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# %%
numerical_cols =["age","resting_blood_pressure","cholestroral","Max_heart_rate","oldpeak","vessels_colored_by_flourosopy"]
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)
print("Training Accuracy:", accuracy_score(y_train, rf_model.predict(X_train)))
print(" Testing Accuracy: ", accuracy_score(y_test, y_pred_rf))
# Out:
# Training Accuracy: 1.0
#  Testing Accuracy:  0.9617021276595744

# %%
print("Classification Report of Random Forest")
print(classification_report(y_test, y_pred_rf))
# Out:
# Classification Report of Random Forest
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       105
#            1       0.95      0.98      0.97       130
#
#     accuracy                           0.96       235
#    macro avg       0.96      0.96      0.96       235
# weighted avg       0.96      0.96      0.96       235

# %%
from sklearn.metrics import  roc_auc_score,  roc_curve,ConfusionMatrixDisplay, auc
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold

# %%
from IPython.display import display, HTML
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_models(X_train, y_train, X_test, y_test, models=None):
    """
    Evaluate multiple machine learning models and generate beautiful reports with visualizations.
    Also identifies whether models overfit, underfit, or are well-generalized.
    """

    # Default models if none provided
    if models is None:
        models = {
            "KNN": KNeighborsClassifier(),                    
            "Logistic Regression": LogisticRegression(max_iter=1000),
            "Naive Bayes": GaussianNB(),                      
            "Random Forest": RandomForestClassifier(),        # <--- Added here
            "Gradient Boosting": GradientBoostingClassifier(),
            "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
        }

    black_box_models = {"Gradient Boosting", "XGBoost", "Random Forest"}
    white_box_models = {"KNN", "Logistic Regression", "Naive Bayes"}

    results = []

    display(HTML("""
        <style>
            .report-table {
                color: #222;
                background-color: white;
                border-collapse: collapse;
                width: 100%;
            }
            .report-table th {
                background-color: #2e6c80;
                color: white;
                padding: 8px;
                text-align: center;
            }
            .report-table td {
                color: #4682b4;
                padding: 8px;
                text-align: center;
                border: 1px solid #ddd;
            }
        </style>
    """))

    display(HTML("<h1 style='color:#2e6c80; text-align:center;'>Machine Learning Model Evaluation Report</h1>"))
    display(HTML("<hr style='border:2px solid #2e6c80'>"))

    for name, model in models.items():
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else [0]*len(y_test)

        training_accuracy = accuracy_score(y_train, model.predict(X_train))
        testing_accuracy = accuracy_score(y_test, y_pred)
        report = classification_report(y_test, y_pred, output_dict=True)
        fpr, tpr, _ = roc_curve(y_test, y_prob)
        roc_auc = auc(fpr, tpr)

        fit_status = "Well-Generalized"
        if training_accuracy - testing_accuracy > 0.1:
            fit_status = "Overfitting"
        elif testing_accuracy - training_accuracy > 0.1:
            fit_status = "Underfitting"

        model_type = "Black Box Model" if name in black_box_models else "White Box Model"

        results.append({
            'Model': name,
            'Training Accuracy': training_accuracy,
            'Testing Accuracy': testing_accuracy,
            'Precision': report['weighted avg']['precision'],
            'Recall': report['weighted avg']['recall'],
            'F1-Score': report['weighted avg']['f1-score'],
            'ROC AUC': roc_auc,
            'Fit Status': fit_status
        })

        display(HTML(f"""
            <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
                <h2 style='color:#2e6c80;'>{name} Evaluation</h2>
                <h4 style='color:#444; font-style:italic; margin-top:-10px;'>{model_type}</h4>
                <h3 style='color:#4682b4;'>Classification Metrics</h3>
                {pd.DataFrame(report).round(4).to_html(classes='report-table')}
                <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
                    <strong>Training Accuracy:</strong> {training_accuracy:.4f} &nbsp; | &nbsp;
                    <strong>Testing Accuracy:</strong> {testing_accuracy:.4f} &nbsp; | &nbsp;
                    <strong>ROC AUC:</strong> {roc_auc:.4f} &nbsp; | &nbsp;
                    <strong>Status:</strong> <span style='font-weight:bold;'>{fit_status}</span>
                </div>
            </div>
        """))

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        fig.suptitle(f'{name} Performance Evaluation', fontsize=16, y=1.05)

        cm = confusion_matrix(y_test, y_pred)
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax1,
                    xticklabels=['Predicted 0', 'Predicted 1'],
                    yticklabels=['Actual 0', 'Actual 1'])
        ax1.set_title("Confusion Matrix")
        ax1.set_xlabel("Predicted")
        ax1.set_ylabel("Actual")

        ax2.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})", color='darkorange')
        ax2.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
        ax2.set_xlabel("False Positive Rate")
        ax2.set_ylabel("True Positive Rate")
        ax2.set_title("ROC Curve")
        ax2.legend(loc="lower right")

        plt.tight_layout()
        plt.show()
        plt.close()

    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('Testing Accuracy', ascending=False)

    display(HTML("<h2 style='color:#2e6c80; text-align:center;'>Model Performance Summary</h2>"))

    styled_table = results_df.style \
        .background_gradient(cmap='Blues', subset=['Testing Accuracy', 'ROC AUC']) \
        .set_properties(**{'text-align': 'center', 'border': '1px solid white'}) \
        .set_table_styles([{
            'selector': 'th',
            'props': [
                ('background-color', '#2e6c80'),
                ('color', 'white'),
                ('text-align', 'center')
            ]
        }])

    display(HTML(styled_table.to_html()))

    return results_df

# %%
results = evaluate_models(X_train, y_train, X_test, y_test)
# Out:
#         <style>
#             .report-table {
#                 color: #222;
#                 background-color: white;
#                 border-collapse: collapse;
#                 width: 100%;
#             }
#             .report-table th {
#                 background-color: #2e6c80;
#                 color: white;
#                 padding: 8px;
#                 text-align: center;
#             }
#             .report-table td {
#                 color: #4682b4;
#                 padding: 8px;
#                 text-align: center;
#                 border: 1px solid #ddd;
#             }
#         </style>
# <h1 style='color:#2e6c80; text-align:center;'>Machine Learning Model Evaluation Report</h1>
# <hr style='border:2px solid #2e6c80'>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>KNN Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>White Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.7414</td>
#       <td>0.8403</td>
#       <td>0.7915</td>
#       <td>0.7909</td>
#       <td>0.7961</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.8190</td>
#       <td>0.7692</td>
#       <td>0.7915</td>
#       <td>0.7941</td>
#       <td>0.7915</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.7783</td>
#       <td>0.8032</td>
#       <td>0.7915</td>
#       <td>0.7907</td>
#       <td>0.7921</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.7915</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 0.9096 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.7915 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.9085 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Overfitting</span>
#                 </div>
#             </div>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>Logistic Regression Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>White Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.7843</td>
#       <td>0.8120</td>
#       <td>0.8</td>
#       <td>0.7982</td>
#       <td>0.7996</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.7619</td>
#       <td>0.8308</td>
#       <td>0.8</td>
#       <td>0.7963</td>
#       <td>0.8000</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.7729</td>
#       <td>0.8213</td>
#       <td>0.8</td>
#       <td>0.7971</td>
#       <td>0.7997</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.8</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 0.8096 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.8000 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.8716 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>Naive Bayes Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>White Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.7524</td>
#       <td>0.8</td>
#       <td>0.7787</td>
#       <td>0.7762</td>
#       <td>0.7787</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.7524</td>
#       <td>0.8</td>
#       <td>0.7787</td>
#       <td>0.7762</td>
#       <td>0.7787</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.7524</td>
#       <td>0.8</td>
#       <td>0.7787</td>
#       <td>0.7762</td>
#       <td>0.7787</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0</td>
#       <td>0.7787</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 0.8032 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.7787 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.8640 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>Random Forest Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>Black Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.9804</td>
#       <td>0.9624</td>
#       <td>0.9702</td>
#       <td>0.9714</td>
#       <td>0.9704</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.9524</td>
#       <td>0.9846</td>
#       <td>0.9702</td>
#       <td>0.9685</td>
#       <td>0.9702</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.9662</td>
#       <td>0.9734</td>
#       <td>0.9702</td>
#       <td>0.9698</td>
#       <td>0.9702</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.9702</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 1.0000 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.9702 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.9898 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>Gradient Boosting Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>Black Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.9159</td>
#       <td>0.9453</td>
#       <td>0.9319</td>
#       <td>0.9306</td>
#       <td>0.9322</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.9333</td>
#       <td>0.9308</td>
#       <td>0.9319</td>
#       <td>0.9321</td>
#       <td>0.9319</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.9245</td>
#       <td>0.9380</td>
#       <td>0.9319</td>
#       <td>0.9313</td>
#       <td>0.9320</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.9319</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 0.9691 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.9319 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.9601 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
# C:\Users\ESHOP\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [10:09:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>XGBoost Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>Black Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.9615</td>
#       <td>0.9618</td>
#       <td>0.9617</td>
#       <td>0.9617</td>
#       <td>0.9617</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.9524</td>
#       <td>0.9692</td>
#       <td>0.9617</td>
#       <td>0.9608</td>
#       <td>0.9617</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.9569</td>
#       <td>0.9655</td>
#       <td>0.9617</td>
#       <td>0.9612</td>
#       <td>0.9617</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.9617</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 1.0000 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.9617 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.9858 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
# <h2 style='color:#2e6c80; text-align:center;'>Model Performance Summary</h2>
# <style type="text/css">
# #T_cce13 th {
#   background-color: #2e6c80;
#   color: white;
#   text-align: center;
# }
# #T_cce13_row0_col0, #T_cce13_row0_col1, #T_cce13_row0_col3, #T_cce13_row0_col4, #T_cce13_row0_col5, #T_cce13_row0_col7, #T_cce13_row1_col0, #T_cce13_row1_col1, #T_cce13_row1_col3, #T_cce13_row1_col4, #T_cce13_row1_col5, #T_cce13_row1_col7, #T_cce13_row2_col0, #T_cce13_row2_col1, #T_cce13_row2_col3, #T_cce13_row2_col4, #T_cce13_row2_col5, #T_cce13_row2_col7, #T_cce13_row3_col0, #T_cce13_row3_col1, #T_cce13_row3_col3, #T_cce13_row3_col4, #T_cce13_row3_col5, #T_cce13_row3_col7, #T_cce13_row4_col0, #T_cce13_row4_col1, #T_cce13_row4_col3, #T_cce13_row4_col4, #T_cce13_row4_col5, #T_cce13_row4_col7, #T_cce13_row5_col0, #T_cce13_row5_col1, #T_cce13_row5_col3, #T_cce13_row5_col4, #T_cce13_row5_col5, #T_cce13_row5_col7 {
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row0_col2, #T_cce13_row0_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row1_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row1_col6 {
#   background-color: #083877;
#   color: #f1f1f1;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row2_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row2_col6 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row3_col2 {
#   background-color: #e1edf8;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row3_col6 {
#   background-color: #ebf3fb;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row4_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row4_col6 {
#   background-color: #a5cde3;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# #T_cce13_row5_col2, #T_cce13_row5_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# </style>
# <table id="T_cce13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cce13_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cce13_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_cce13_level0_col2" class="col_heading level0 col2" >Testing Accuracy</th>
#       <th id="T_cce13_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_cce13_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_cce13_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_cce13_level0_col6" class="col_heading level0 col6" >ROC AUC</th>
#       <th id="T_cce13_level0_col7" class="col_heading level0 col7" >Fit Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cce13_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_cce13_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_cce13_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_cce13_row0_col2" class="data row0 col2" >0.970213</td>
#       <td id="T_cce13_row0_col3" class="data row0 col3" >0.970442</td>
#       <td id="T_cce13_row0_col4" class="data row0 col4" >0.970213</td>
#       <td id="T_cce13_row0_col5" class="data row0 col5" >0.970167</td>
#       <td id="T_cce13_row0_col6" class="data row0 col6" >0.989780</td>
#       <td id="T_cce13_row0_col7" class="data row0 col7" >Well-Generalized</td>
#     </tr>
#     <tr>
#       <th id="T_cce13_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_cce13_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_cce13_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cce13_row1_col2" class="data row1 col2" >0.961702</td>
#       <td id="T_cce13_row1_col3" class="data row1 col3" >0.961701</td>
#       <td id="T_cce13_row1_col4" class="data row1 col4" >0.961702</td>
#       <td id="T_cce13_row1_col5" class="data row1 col5" >0.961684</td>
#       <td id="T_cce13_row1_col6" class="data row1 col6" >0.985788</td>
#       <td id="T_cce13_row1_col7" class="data row1 col7" >Well-Generalized</td>
#     </tr>
#     <tr>
#       <th id="T_cce13_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_cce13_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_cce13_row2_col1" class="data row2 col1" >0.969149</td>
#       <td id="T_cce13_row2_col2" class="data row2 col2" >0.931915</td>
#       <td id="T_cce13_row2_col3" class="data row2 col3" >0.932165</td>
#       <td id="T_cce13_row2_col4" class="data row2 col4" >0.931915</td>
#       <td id="T_cce13_row2_col5" class="data row2 col5" >0.931972</td>
#       <td id="T_cce13_row2_col6" class="data row2 col6" >0.960073</td>
#       <td id="T_cce13_row2_col7" class="data row2 col7" >Well-Generalized</td>
#     </tr>
#     <tr>
#       <th id="T_cce13_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_cce13_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_cce13_row3_col1" class="data row3 col1" >0.809574</td>
#       <td id="T_cce13_row3_col2" class="data row3 col2" >0.800000</td>
#       <td id="T_cce13_row3_col3" class="data row3 col3" >0.799646</td>
#       <td id="T_cce13_row3_col4" class="data row3 col4" >0.800000</td>
#       <td id="T_cce13_row3_col5" class="data row3 col5" >0.799691</td>
#       <td id="T_cce13_row3_col6" class="data row3 col6" >0.871648</td>
#       <td id="T_cce13_row3_col7" class="data row3 col7" >Well-Generalized</td>
#     </tr>
#     <tr>
#       <th id="T_cce13_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_cce13_row4_col0" class="data row4 col0" >KNN</td>
#       <td id="T_cce13_row4_col1" class="data row4 col1" >0.909574</td>
#       <td id="T_cce13_row4_col2" class="data row4 col2" >0.791489</td>
#       <td id="T_cce13_row4_col3" class="data row4 col3" >0.796121</td>
#       <td id="T_cce13_row4_col4" class="data row4 col4" >0.791489</td>
#       <td id="T_cce13_row4_col5" class="data row4 col5" >0.792073</td>
#       <td id="T_cce13_row4_col6" class="data row4 col6" >0.908498</td>
#       <td id="T_cce13_row4_col7" class="data row4 col7" >Overfitting</td>
#     </tr>
#     <tr>
#       <th id="T_cce13_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_cce13_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_cce13_row5_col1" class="data row5 col1" >0.803191</td>
#       <td id="T_cce13_row5_col2" class="data row5 col2" >0.778723</td>
#       <td id="T_cce13_row5_col3" class="data row5 col3" >0.778723</td>
#       <td id="T_cce13_row5_col4" class="data row5 col4" >0.778723</td>
#       <td id="T_cce13_row5_col5" class="data row5 col5" >0.778723</td>
#       <td id="T_cce13_row5_col6" class="data row5 col6" >0.863956</td>
#       <td id="T_cce13_row5_col7" class="data row5 col7" >Well-Generalized</td>
#     </tr>
#   </tbody>
# </table>

# %%
def check_overfitting_underfitting(results_df, threshold=0.05):
    """
    Checks each model for signs of overfitting or underfitting based on training vs. testing accuracy.

    Parameters:
    results_df: DataFrame from evaluate_models()
    threshold: Accuracy gap threshold to consider overfitting

    Returns:
    DataFrame with additional column: 'Model Fit Status'
    """
    fit_status = []

    for _, row in results_df.iterrows():
        train_acc = row['Training Accuracy']
        test_acc = row['Testing Accuracy']
        acc_diff = train_acc - test_acc

        if train_acc < 0.75 and test_acc < 0.75:
            status = 'Underfitting'
        elif acc_diff > threshold:
            status = 'Overfitting'
        else:
            status = 'Good Fit'

        fit_status.append(status)

    results_df['Model Fit Status'] = fit_status

    display(HTML("<h2 style='color:#2e6c80; text-align:center;'>Overfitting/Underfitting Analysis</h2>"))
    display(results_df[['Model', 'Training Accuracy', 'Testing Accuracy', 'Model Fit Status']].style
            .applymap(lambda x: 'background-color:#ffa07a' if x == 'Overfitting' else
                      'background-color:#f0e68c' if x == 'Underfitting' else
                      'background-color:#2e8b57', subset=['Model Fit Status']))

    return results_df

# Remove the incorrect indentation from the line below
result_df = check_overfitting_underfitting(results)
# Out:
# <h2 style='color:#2e6c80; text-align:center;'>Overfitting/Underfitting Analysis</h2>
# C:\Users\ESHOP\AppData\Local\Temp\ipykernel_10444\3257569977.py:32: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(lambda x: 'background-color:#ffa07a' if x == 'Overfitting' else
# <style type="text/css">
# #T_e35ae_row0_col3, #T_e35ae_row1_col3, #T_e35ae_row2_col3, #T_e35ae_row3_col3, #T_e35ae_row5_col3 {
#   background-color: #2e8b57;
# }
# #T_e35ae_row4_col3 {
#   background-color: #ffa07a;
# }
# </style>
# <table id="T_e35ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e35ae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e35ae_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_e35ae_level0_col2" class="col_heading level0 col2" >Testing Accuracy</th>
#       <th id="T_e35ae_level0_col3" class="col_heading level0 col3" >Model Fit Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e35ae_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e35ae_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_e35ae_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_e35ae_row0_col2" class="data row0 col2" >0.970213</td>
#       <td id="T_e35ae_row0_col3" class="data row0 col3" >Good Fit</td>
#     </tr>
#     <tr>
#       <th id="T_e35ae_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e35ae_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_e35ae_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e35ae_row1_col2" class="data row1 col2" >0.961702</td>
#       <td id="T_e35ae_row1_col3" class="data row1 col3" >Good Fit</td>
#     </tr>
#     <tr>
#       <th id="T_e35ae_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_e35ae_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_e35ae_row2_col1" class="data row2 col1" >0.969149</td>
#       <td id="T_e35ae_row2_col2" class="data row2 col2" >0.931915</td>
#       <td id="T_e35ae_row2_col3" class="data row2 col3" >Good Fit</td>
#     </tr>
#     <tr>
#       <th id="T_e35ae_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_e35ae_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_e35ae_row3_col1" class="data row3 col1" >0.809574</td>
#       <td id="T_e35ae_row3_col2" class="data row3 col2" >0.800000</td>
#       <td id="T_e35ae_row3_col3" class="data row3 col3" >Good Fit</td>
#     </tr>
#     <tr>
#       <th id="T_e35ae_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_e35ae_row4_col0" class="data row4 col0" >KNN</td>
#       <td id="T_e35ae_row4_col1" class="data row4 col1" >0.909574</td>
#       <td id="T_e35ae_row4_col2" class="data row4 col2" >0.791489</td>
#       <td id="T_e35ae_row4_col3" class="data row4 col3" >Overfitting</td>
#     </tr>
#     <tr>
#       <th id="T_e35ae_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_e35ae_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_e35ae_row5_col1" class="data row5 col1" >0.803191</td>
#       <td id="T_e35ae_row5_col2" class="data row5 col2" >0.778723</td>
#       <td id="T_e35ae_row5_col3" class="data row5 col3" >Good Fit</td>
#     </tr>
#   </tbody>
# </table>

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}


grid_search = GridSearchCV(RandomForestClassifier(random_state=42),param_grid=param_grid,
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')
# Fit to the training data
grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)


best_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# C:\Users\ESHOP\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Best Accuracy: 0.9585106382978724

# %%
y_pred = best_model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.9744680851063829
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       105
#            1       0.96      0.99      0.98       130
#
#     accuracy                           0.97       235
#    macro avg       0.98      0.97      0.97       235
# weighted avg       0.97      0.97      0.97       235

# %%
# Define the dictionary containing the best Gradient Boosting model
models_to_evaluate = {"Randome Forest": best_model}

# Call the evaluate_models function with the dictionary
evaluate_models(X_train, y_train, X_test, y_test, models_to_evaluate)
# Out:
#         <style>
#             .report-table {
#                 color: #222;
#                 background-color: white;
#                 border-collapse: collapse;
#                 width: 100%;
#             }
#             .report-table th {
#                 background-color: #2e6c80;
#                 color: white;
#                 padding: 8px;
#                 text-align: center;
#             }
#             .report-table td {
#                 color: #4682b4;
#                 padding: 8px;
#                 text-align: center;
#                 border: 1px solid #ddd;
#             }
#         </style>
# <h1 style='color:#2e6c80; text-align:center;'>Machine Learning Model Evaluation Report</h1>
# <hr style='border:2px solid #2e6c80'>
#             <div style='background-color:#f0f8ff; padding:15px; border-radius:10px; margin-bottom:20px;'>
#                 <h2 style='color:#2e6c80;'>Randome Forest Evaluation</h2>
#                 <h4 style='color:#444; font-style:italic; margin-top:-10px;'>White Box Model</h4>
#                 <h3 style='color:#4682b4;'>Classification Metrics</h3>
#                 <table border="1" class="dataframe report-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>accuracy</th>
#       <th>macro avg</th>
#       <th>weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>precision</th>
#       <td>0.9901</td>
#       <td>0.9627</td>
#       <td>0.9745</td>
#       <td>0.9764</td>
#       <td>0.9749</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.9524</td>
#       <td>0.9923</td>
#       <td>0.9745</td>
#       <td>0.9723</td>
#       <td>0.9745</td>
#     </tr>
#     <tr>
#       <th>f1-score</th>
#       <td>0.9709</td>
#       <td>0.9773</td>
#       <td>0.9745</td>
#       <td>0.9741</td>
#       <td>0.9744</td>
#     </tr>
#     <tr>
#       <th>support</th>
#       <td>105.0000</td>
#       <td>130.0000</td>
#       <td>0.9745</td>
#       <td>235.0000</td>
#       <td>235.0000</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style="margin-top:10px; font-size:16px; color:#2e6c80;">
#                     <strong>Training Accuracy:</strong> 0.9926 &nbsp; | &nbsp;
#                     <strong>Testing Accuracy:</strong> 0.9745 &nbsp; | &nbsp;
#                     <strong>ROC AUC:</strong> 0.9900 &nbsp; | &nbsp;
#                     <strong>Status:</strong> <span style='font-weight:bold;'>Well-Generalized</span>
#                 </div>
#             </div>
# <h2 style='color:#2e6c80; text-align:center;'>Model Performance Summary</h2>
# <style type="text/css">
# #T_3057e th {
#   background-color: #2e6c80;
#   color: white;
#   text-align: center;
# }
# #T_3057e_row0_col0, #T_3057e_row0_col1, #T_3057e_row0_col3, #T_3057e_row0_col4, #T_3057e_row0_col5, #T_3057e_row0_col7 {
#   text-align: center;
#   border: 1px solid white;
# }
# #T_3057e_row0_col2, #T_3057e_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   border: 1px solid white;
# }
# </style>
# <table id="T_3057e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3057e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3057e_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_3057e_level0_col2" class="col_heading level0 col2" >Testing Accuracy</th>
#       <th id="T_3057e_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_3057e_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_3057e_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_3057e_level0_col6" class="col_heading level0 col6" >ROC AUC</th>
#       <th id="T_3057e_level0_col7" class="col_heading level0 col7" >Fit Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3057e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3057e_row0_col0" class="data row0 col0" >Randome Forest</td>
#       <td id="T_3057e_row0_col1" class="data row0 col1" >0.992553</td>
#       <td id="T_3057e_row0_col2" class="data row0 col2" >0.974468</td>
#       <td id="T_3057e_row0_col3" class="data row0 col3" >0.974935</td>
#       <td id="T_3057e_row0_col4" class="data row0 col4" >0.974468</td>
#       <td id="T_3057e_row0_col5" class="data row0 col5" >0.974414</td>
#       <td id="T_3057e_row0_col6" class="data row0 col6" >0.989963</td>
#       <td id="T_3057e_row0_col7" class="data row0 col7" >Well-Generalized</td>
#     </tr>
#   </tbody>
# </table>
#             Model  Training Accuracy  Testing Accuracy  Precision    Recall  \
# 0  Randome Forest           0.992553          0.974468   0.974935  0.974468
#
#    F1-Score   ROC AUC        Fit Status
# 0  0.974414  0.989963  Well-Generalized

# %%
# import joblib
# rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# rf_model.fit(X_train, y_train)

# # Save the model
# joblib.dump(rf_model, 'heart_prediction_model.pkl')
# print("Model saved as heart_prediction_model.pkl")

# %%
importances = best_model.feature_importances_
feature_names = X_train.columns

# Create a DataFrame
feat_imp = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Display top features
print(feat_imp)

# Plot feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feat_imp)
plt.title('Feature Importances from Random Forest')
plt.tight_layout()
plt.show()
# Out:
#                           Feature  Importance
# 7                  Max_heart_rate    0.130750
# 12                    thalassemia    0.121344
# 9                         oldpeak    0.113547
# 0                             age    0.113270
# 11  vessels_colored_by_flourosopy    0.113123
# 2                 chest_pain_type    0.102139
# 4                     cholestoral    0.094329
# 3          resting_blood_pressure    0.075904
# 8         exercise_induced_angina    0.049494
# 10                          slope    0.036630
# 1                             sex    0.025005
# 6                        rest_ecg    0.024464
# 5             fasting_blood_sugar    0.000000

# %%
import shap

# Create the SHAP explainer
explainer = shap.Explainer(best_model, X_train)

# Compute SHAP values
shap_values = explainer(X_test)
# Out:
#  97%|=================== | 454/470 [00:27<00:00]

# %%
plt.figure(figsize=(8,4))
print("SHAP Summary Plot (Global Feature Importance):")
shap.summary_plot(shap_values, X_test)
# Out:
# SHAP Summary Plot (Global Feature Importance):

# %%
# Calculate the mean absolute SHAP values
mean_abs_shap_values = np.abs(shap_values.values).mean(axis=0)

# Create a DataFrame to visualize feature importance
feature_importance_df = pd.DataFrame({
    'Feature': X_test.columns,
    'Mean Absolute SHAP Value': mean_abs_shap_values
}).sort_values(by='Mean Absolute SHAP Value', ascending=False)

print(feature_importance_df)

# %%
shap.plots.bar(shap_values)

# %%
# Feature importance plot
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
shap.plots.waterfall(shap_values[0, :, 0])

# %%
shap.plots.waterfall(shap_values[0, :, 1])

# %%
feature_importance_df = pd.DataFrame({
    'Feature': X_test.columns,
    'Mean Absolute SHAP Value': mean_abs_shap_values_per_feature
}).sort_values(by='Mean Absolute SHAP Value', ascending=False)

print(feature_importance_df)
# Out:
#                           Feature  Mean Absolute SHAP Value
# 11  vessels_colored_by_flourosopy                  0.089842
# 12                    thalassemia                  0.087374
# 9                         oldpeak                  0.069765
# 2                 chest_pain_type                  0.067094
# 7                  Max_heart_rate                  0.051513
# 0                             age                  0.050310
# 8         exercise_induced_angina                  0.040442
# 4                     cholestoral                  0.027371
# 10                          slope                  0.024935
# 1                             sex                  0.024198
# 3          resting_blood_pressure                  0.022541
# 6                        rest_ecg                  0.019632
# 5             fasting_blood_sugar                  0.000000
